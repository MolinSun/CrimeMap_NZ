# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Wellington.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#        Area Unit                                    ANZSOC Division  \
# 0       Adelaide                      Acts Intended to Cause Injury
# 1       Adelaide                      Acts Intended to Cause Injury
# 2       Adelaide                      Acts Intended to Cause Injury
# 3       Adelaide                      Acts Intended to Cause Injury
# 4       Adelaide                      Acts Intended to Cause Injury
# ...          ...                                                ...
# 10788  Woodridge  Unlawful Entry With Intent/Burglary, Break and...
# 10789  Woodridge  Unlawful Entry With Intent/Burglary, Break and...
# 10790  Woodridge  Unlawful Entry With Intent/Burglary, Break and...
# 10791  Woodridge  Unlawful Entry With Intent/Burglary, Break and...
# 10792  Woodridge  Unlawful Entry With Intent/Burglary, Break and...
#
#        Year Month             Region  Victimisations
# 0      2020-01-01  Wellington Region               3
# 1      2021-01-01  Wellington Region               8
# 2      2022-01-01  Wellington Region               1
# 3      2020-02-01  Wellington Region               4
# 4      2021-02-01  Wellington Region               2
# ...           ...                ...             ...
# 10788  2022-01-01  Wellington Region               1
# 10789  2020-04-01  Wellington Region               1
# 10790  2021-07-01  Wellington Region               4
# 10791  2021-08-01  Wellington Region               2
# 10792  2021-11-01  Wellington Region               2
#
# [10793 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#        Area Unit                                    ANZSOC Division  Year  \
# 0       Adelaide                      Acts Intended to Cause Injury  2020
# 1       Adelaide                      Acts Intended to Cause Injury  2021
# 2       Adelaide                      Acts Intended to Cause Injury  2022
# 3       Adelaide                      Acts Intended to Cause Injury  2020
# 4       Adelaide                      Acts Intended to Cause Injury  2021
# ...          ...                                                ...   ...
# 10788  Woodridge  Unlawful Entry With Intent/Burglary, Break and...  2022
# 10789  Woodridge  Unlawful Entry With Intent/Burglary, Break and...  2020
# 10790  Woodridge  Unlawful Entry With Intent/Burglary, Break and...  2021
# 10791  Woodridge  Unlawful Entry With Intent/Burglary, Break and...  2021
# 10792  Woodridge  Unlawful Entry With Intent/Burglary, Break and...  2021
#
#                   Region  Victimisations
# 0      Wellington Region               3
# 1      Wellington Region               8
# 2      Wellington Region               1
# 3      Wellington Region               4
# 4      Wellington Region               2
# ...                  ...             ...
# 10788  Wellington Region               1
# 10789  Wellington Region               1
# 10790  Wellington Region               4
# 10791  Wellington Region               2
# 10792  Wellington Region               2
#
# [10793 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Weillington.csv", sep="\t", encoding="utf-16")
df = df[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/m1/_mvcxs8x2nggqmq9qg1y8yth0000gn/T/ipykernel_24596/259259151.py in <module>
# ----> 1 df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Wellington.csv", sep="\t", encoding="utf-16")
#       2 df = df[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
#       3 df.index = range(len(df))
#       4 df['Year'] = df['Year Month'].str[5:]
#       5 df['Month'] = df['Year Month'].str[2:4]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Wellington.csv'
