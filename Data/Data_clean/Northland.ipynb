# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Northland.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#         Area Unit                                    ANZSOC Division  \
# 0     Abbey Caves                      Acts Intended to Cause Injury
# 1     Abbey Caves                      Acts Intended to Cause Injury
# 2     Abbey Caves            Robbery, Extortion and Related Offences
# 3     Abbey Caves                         Theft and Related Offences
# 4     Abbey Caves                         Theft and Related Offences
# ...           ...                                                ...
# 5020     Woodhill  Unlawful Entry With Intent/Burglary, Break and...
# 5021     Woodhill  Unlawful Entry With Intent/Burglary, Break and...
# 5022     Woodhill  Unlawful Entry With Intent/Burglary, Break and...
# 5023     Woodhill  Unlawful Entry With Intent/Burglary, Break and...
# 5024     Woodhill  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year Month     Region  Victimisations
# 0     2020-06-01  Northland               1
# 1     2020-08-01  Northland               1
# 2     2022-01-01  Northland               1
# 3     2020-01-01  Northland               1
# 4     2022-01-01  Northland               1
# ...          ...        ...             ...
# 5020  2020-11-01  Northland               1
# 5021  2021-11-01  Northland               4
# 5022  2022-11-01  Northland               2
# 5023  2020-12-01  Northland               1
# 5024  2022-12-01  Northland               2
#
# [5025 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#         Area Unit                                    ANZSOC Division  Year  \
# 0     Abbey Caves                      Acts Intended to Cause Injury  2020
# 1     Abbey Caves                      Acts Intended to Cause Injury  2020
# 2     Abbey Caves            Robbery, Extortion and Related Offences  2022
# 3     Abbey Caves                         Theft and Related Offences  2020
# 4     Abbey Caves                         Theft and Related Offences  2022
# ...           ...                                                ...   ...
# 5020     Woodhill  Unlawful Entry With Intent/Burglary, Break and...  2020
# 5021     Woodhill  Unlawful Entry With Intent/Burglary, Break and...  2021
# 5022     Woodhill  Unlawful Entry With Intent/Burglary, Break and...  2022
# 5023     Woodhill  Unlawful Entry With Intent/Burglary, Break and...  2020
# 5024     Woodhill  Unlawful Entry With Intent/Burglary, Break and...  2022
#
#          Region  Victimisations
# 0     Northland               1
# 1     Northland               1
# 2     Northland               1
# 3     Northland               1
# 4     Northland               1
# ...         ...             ...
# 5020  Northland               1
# 5021  Northland               4
# 5022  Northland               2
# 5023  Northland               1
# 5024  Northland               2
#
# [5025 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Northland.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#                       Area Unit  \
# 0                    Kamo West.
# 1                Raumanga East.
# 2                   Kensington.
# 3      Inlet-Whangarei Harbour.
# 4                     Ngunguru.
# ...                         ...
# 10923        Whangarei Central.
# 10924                  Kaikohe.
# 10925       Wharekohe-Oakleigh.
# 10926           Bay of Islands.
# 10927                 Horahora.
#
#                                          ANZSOC Division  Year  \
# 0                             Theft and Related Offences  2023
# 1                             Theft and Related Offences  2023
# 2                          Acts Intended to Cause Injury  2023
# 3                             Theft and Related Offences  2023
# 4                    Sexual Assault and Related Offences  2023
# ...                                                  ...   ...
# 10923                         Theft and Related Offences  2023
# 10924                         Theft and Related Offences  2023
# 10925                         Theft and Related Offences  2023
# 10926  Unlawful Entry With Intent/Burglary, Break and...  2023
# 10927                      Acts Intended to Cause Injury  2023
#
#                  Region  Victimisations
# 0      Northland Region               1
# 1      Northland Region               1
# 2      Northland Region               1
# 3      Northland Region               1
# 4      Northland Region               1
# ...                 ...             ...
# 10923  Northland Region               1
# 10924  Northland Region               2
# 10925  Northland Region               1
# 10926  Northland Region               2
# 10927  Northland Region               1
#
# [10928 rows x 5 columns]

# %%
df['Region'] = 'Northland'

# %%
final = pd.concat([df, df_all], ignore_index=True)
final
# Out:
#                       Area Unit  \
# 0                    Kamo West.
# 1                Raumanga East.
# 2                   Kensington.
# 3      Inlet-Whangarei Harbour.
# 4                     Ngunguru.
# ...                         ...
# 15948                  Woodhill
# 15949                  Woodhill
# 15950                  Woodhill
# 15951                  Woodhill
# 15952                  Woodhill
#
#                                          ANZSOC Division  Year  \
# 0                             Theft and Related Offences  2023
# 1                             Theft and Related Offences  2023
# 2                          Acts Intended to Cause Injury  2023
# 3                             Theft and Related Offences  2023
# 4                    Sexual Assault and Related Offences  2023
# ...                                                  ...   ...
# 15948  Unlawful Entry With Intent/Burglary, Break and...  2020
# 15949  Unlawful Entry With Intent/Burglary, Break and...  2021
# 15950  Unlawful Entry With Intent/Burglary, Break and...  2022
# 15951  Unlawful Entry With Intent/Burglary, Break and...  2020
# 15952  Unlawful Entry With Intent/Burglary, Break and...  2022
#
#                  Region  Victimisations
# 0      Northland Region               1
# 1      Northland Region               1
# 2      Northland Region               1
# 3      Northland Region               1
# 4      Northland Region               1
# ...                 ...             ...
# 15948         Northland               1
# 15949         Northland               4
# 15950         Northland               2
# 15951         Northland               1
# 15952         Northland               2
#
# [15953 rows x 5 columns]
