# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Waikato.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#         Area Unit                                    ANZSOC Division  \
# 0      Acacia Bay                      Acts Intended to Cause Injury
# 1      Acacia Bay                      Acts Intended to Cause Injury
# 2      Acacia Bay                      Acts Intended to Cause Injury
# 3      Acacia Bay                      Acts Intended to Cause Injury
# 4      Acacia Bay                      Acts Intended to Cause Injury
# ...           ...                                                ...
# 11667   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...
# 11668   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...
# 11669   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...
# 11670   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...
# 11671   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...
#
#        Year Month          Region  Victimisations
# 0      2020-02-01  Waikato Region               1
# 1      2021-02-01  Waikato Region               1
# 2      2020-05-01  Waikato Region               1
# 3      2022-05-01  Waikato Region               2
# 4      2021-06-01  Waikato Region               1
# ...           ...             ...             ...
# 11667  2022-09-01  Waikato Region               2
# 11668  2020-11-01  Waikato Region               2
# 11669  2022-11-01  Waikato Region               2
# 11670  2020-12-01  Waikato Region               2
# 11671  2022-12-01  Waikato Region               2
#
# [11672 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#         Area Unit                                    ANZSOC Division  Year  \
# 0      Acacia Bay                      Acts Intended to Cause Injury  2020
# 1      Acacia Bay                      Acts Intended to Cause Injury  2021
# 2      Acacia Bay                      Acts Intended to Cause Injury  2020
# 3      Acacia Bay                      Acts Intended to Cause Injury  2022
# 4      Acacia Bay                      Acts Intended to Cause Injury  2021
# ...           ...                                                ...   ...
# 11667   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...  2022
# 11668   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...  2020
# 11669   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...  2022
# 11670   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...  2020
# 11671   Whitikahu  Unlawful Entry With Intent/Burglary, Break and...  2022
#
#                Region  Victimisations
# 0      Waikato Region               1
# 1      Waikato Region               1
# 2      Waikato Region               1
# 3      Waikato Region               2
# 4      Waikato Region               1
# ...               ...             ...
# 11667  Waikato Region               2
# 11668  Waikato Region               2
# 11669  Waikato Region               2
# 11670  Waikato Region               2
# 11671  Waikato Region               2
#
# [11672 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Waikato.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#                       Area Unit  \
# 0      Inland Water-Lake Taupo.
# 1      Inland Water-Lake Taupo.
# 2             Hamilton Central.
# 3                    Grandview.
# 4      Inland Water-Lake Taupo.
# ...                         ...
# 33650                  Reporoa.
# 33651            Taupo Central.
# 33652                  Turangi.
# 33653           Rangatira Park.
# 33654                  Hilltop.
#
#                                          ANZSOC Division  Year  \
# 0                          Acts Intended to Cause Injury  2023
# 1                             Theft and Related Offences  2023
# 2                          Acts Intended to Cause Injury  2023
# 3                          Acts Intended to Cause Injury  2023
# 4                             Theft and Related Offences  2023
# ...                                                  ...   ...
# 33650  Unlawful Entry With Intent/Burglary, Break and...  2023
# 33651                         Theft and Related Offences  2023
# 33652                         Theft and Related Offences  2023
# 33653                         Theft and Related Offences  2023
# 33654  Abduction, Harassment and Other Related Offenc...  2023
#
#                Region  Victimisations
# 0      Waikato Region               1
# 1      Waikato Region               1
# 2      Waikato Region               1
# 3      Waikato Region               1
# 4      Waikato Region               1
# ...               ...             ...
# 33650  Waikato Region               1
# 33651  Waikato Region               1
# 33652  Waikato Region               1
# 33653  Waikato Region               1
# 33654  Waikato Region               1
#
# [33655 rows x 5 columns]

# %%
final = pd.concat([df, df_all], ignore_index=True)
final
# Out:
#                       Area Unit  \
# 0      Inland Water-Lake Taupo.
# 1      Inland Water-Lake Taupo.
# 2             Hamilton Central.
# 3                    Grandview.
# 4      Inland Water-Lake Taupo.
# ...                         ...
# 45322                 Whitikahu
# 45323                 Whitikahu
# 45324                 Whitikahu
# 45325                 Whitikahu
# 45326                 Whitikahu
#
#                                          ANZSOC Division  Year  \
# 0                          Acts Intended to Cause Injury  2023
# 1                             Theft and Related Offences  2023
# 2                          Acts Intended to Cause Injury  2023
# 3                          Acts Intended to Cause Injury  2023
# 4                             Theft and Related Offences  2023
# ...                                                  ...   ...
# 45322  Unlawful Entry With Intent/Burglary, Break and...  2022
# 45323  Unlawful Entry With Intent/Burglary, Break and...  2020
# 45324  Unlawful Entry With Intent/Burglary, Break and...  2022
# 45325  Unlawful Entry With Intent/Burglary, Break and...  2020
# 45326  Unlawful Entry With Intent/Burglary, Break and...  2022
#
#                Region  Victimisations
# 0      Waikato Region               1
# 1      Waikato Region               1
# 2      Waikato Region               1
# 3      Waikato Region               1
# 4      Waikato Region               1
# ...               ...             ...
# 45322  Waikato Region               2
# 45323  Waikato Region               2
# 45324  Waikato Region               2
# 45325  Waikato Region               2
# 45326  Waikato Region               2
#
# [45327 rows x 5 columns]

# %%
final.to_csv("/Users/momoko/Desktop/NZ_Crime/Data/F_Data/Waikato.csv")
