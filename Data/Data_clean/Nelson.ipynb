# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Nelson.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#       Area Unit                                    ANZSOC Division  \
# 0       Atawhai                      Acts Intended to Cause Injury
# 1       Atawhai                      Acts Intended to Cause Injury
# 2       Atawhai                      Acts Intended to Cause Injury
# 3       Atawhai                      Acts Intended to Cause Injury
# 4       Atawhai                      Acts Intended to Cause Injury
# ...         ...                                                ...
# 1339  Whangamoa                         Theft and Related Offences
# 1340  Whangamoa                         Theft and Related Offences
# 1341  Whangamoa                         Theft and Related Offences
# 1342  Whangamoa  Unlawful Entry With Intent/Burglary, Break and...
# 1343  Whangamoa  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year Month         Region  Victimisations
# 0     2021-02-01  Nelson Region               2
# 1     2022-03-01  Nelson Region               3
# 2     2022-05-01  Nelson Region               1
# 3     2021-07-01  Nelson Region               2
# 4     2022-07-01  Nelson Region               1
# ...          ...            ...             ...
# 1339  2022-10-01  Nelson Region               1
# 1340  2021-11-01  Nelson Region               2
# 1341  2022-11-01  Nelson Region               1
# 1342  2020-07-01  Nelson Region               1
# 1343  2022-12-01  Nelson Region               1
#
# [1344 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
