# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/BayofPlenty.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#               Area Unit                                    ANZSOC Division  \
# 0     Allandale-Mokorua                      Acts Intended to Cause Injury
# 1     Allandale-Mokorua                      Acts Intended to Cause Injury
# 2     Allandale-Mokorua                      Acts Intended to Cause Injury
# 3     Allandale-Mokorua                      Acts Intended to Cause Injury
# 4     Allandale-Mokorua                      Acts Intended to Cause Injury
# ...                 ...                                                ...
# 7579        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7580        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7581        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7582        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7583        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year Month                Region  Victimisations
# 0     2020-01-01  Bay of Plenty Region               5
# 1     2021-01-01  Bay of Plenty Region               4
# 2     2022-01-01  Bay of Plenty Region               4
# 3     2020-02-01  Bay of Plenty Region               3
# 4     2021-02-01  Bay of Plenty Region               5
# ...          ...                   ...             ...
# 7579  2022-09-01  Bay of Plenty Region               2
# 7580  2021-10-01  Bay of Plenty Region               1
# 7581  2021-11-01  Bay of Plenty Region               1
# 7582  2020-12-01  Bay of Plenty Region               1
# 7583  2022-12-01  Bay of Plenty Region               1
#
# [7584 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#               Area Unit                                    ANZSOC Division  \
# 0     Allandale-Mokorua                      Acts Intended to Cause Injury
# 1     Allandale-Mokorua                      Acts Intended to Cause Injury
# 2     Allandale-Mokorua                      Acts Intended to Cause Injury
# 3     Allandale-Mokorua                      Acts Intended to Cause Injury
# 4     Allandale-Mokorua                      Acts Intended to Cause Injury
# ...                 ...                                                ...
# 7579        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7580        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7581        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7582        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 7583        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year                Region  Victimisations
# 0     2020  Bay of Plenty Region               5
# 1     2021  Bay of Plenty Region               4
# 2     2022  Bay of Plenty Region               4
# 3     2020  Bay of Plenty Region               3
# 4     2021  Bay of Plenty Region               5
# ...    ...                   ...             ...
# 7579  2022  Bay of Plenty Region               2
# 7580  2021  Bay of Plenty Region               1
# 7581  2021  Bay of Plenty Region               1
# 7582  2020  Bay of Plenty Region               1
# 7583  2022  Bay of Plenty Region               1
#
# [7584 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Gisborne.csv", sep="\t", encoding="utf-16")
df = df[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#               Area Unit                          ANZSOC Division  Year  \
# 0               Wainui.               Theft and Related Offences  2023
# 1           Whataupoko.               Theft and Related Offences  2023
# 2     Gisborne Central.               Theft and Related Offences  2023
# 3               Wainui.               Theft and Related Offences  2023
# 4     Gisborne Airport.               Theft and Related Offences  2023
# ...                 ...                                      ...   ...
# 3341  Gisborne Central.  Robbery, Extortion and Related Offences  2023
# 3342         Riverdale.  Robbery, Extortion and Related Offences  2023
# 3343  Gisborne Central.  Robbery, Extortion and Related Offences  2023
# 3344         Mangapapa.  Robbery, Extortion and Related Offences  2023
# 3345       Kaiti South.  Robbery, Extortion and Related Offences  2023
#
#                Region  Victimisations
# 0     Gisborne Region               1
# 1     Gisborne Region               1
# 2     Gisborne Region               1
# 3     Gisborne Region               1
# 4     Gisborne Region               1
# ...               ...             ...
# 3341  Gisborne Region               1
# 3342  Gisborne Region               1
# 3343  Gisborne Region               1
# 3344  Gisborne Region               1
# 3345  Gisborne Region               1
#
# [3346 rows x 5 columns]

# %%
final = pd.concat([df, df_all], ignore_index=True)
final
# Out:
#                Area Unit                                    ANZSOC Division  \
# 0                Wainui.                         Theft and Related Offences
# 1            Whataupoko.                         Theft and Related Offences
# 2      Gisborne Central.                         Theft and Related Offences
# 3                Wainui.                         Theft and Related Offences
# 4      Gisborne Airport.                         Theft and Related Offences
# ...                  ...                                                ...
# 10925        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 10926        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 10927        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 10928        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
# 10929        Yatton Park  Unlawful Entry With Intent/Burglary, Break and...
#
#        Year                Region  Victimisations
# 0      2023       Gisborne Region               1
# 1      2023       Gisborne Region               1
# 2      2023       Gisborne Region               1
# 3      2023       Gisborne Region               1
# 4      2023       Gisborne Region               1
# ...     ...                   ...             ...
# 10925  2022  Bay of Plenty Region               2
# 10926  2021  Bay of Plenty Region               1
# 10927  2021  Bay of Plenty Region               1
# 10928  2020  Bay of Plenty Region               1
# 10929  2022  Bay of Plenty Region               1
#
# [10930 rows x 5 columns]

# %%
final.to_csv("/Users/momoko/Desktop/NZ_Crime/Data/F_Data/BayofPlenty.csv")
