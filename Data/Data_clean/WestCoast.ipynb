# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/WestCoast.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#     Area Unit                                    ANZSOC Division  Year Month  \
# 0      Ahaura                      Acts Intended to Cause Injury  2021-01-01
# 1      Ahaura                      Acts Intended to Cause Injury  2020-02-01
# 2      Ahaura                      Acts Intended to Cause Injury  2022-03-01
# 3      Ahaura                         Theft and Related Offences  2022-03-01
# 4      Ahaura                         Theft and Related Offences  2020-04-01
# ..        ...                                                ...         ...
# 851  Whataroa                         Theft and Related Offences  2022-05-01
# 852  Whataroa                         Theft and Related Offences  2021-06-01
# 853  Whataroa                         Theft and Related Offences  2020-12-01
# 854  Whataroa                         Theft and Related Offences  2021-12-01
# 855  Whataroa  Unlawful Entry With Intent/Burglary, Break and...  2022-05-01
#
#                 Region  Victimisations
# 0    West Coast Region               1
# 1    West Coast Region               1
# 2    West Coast Region               1
# 3    West Coast Region               2
# 4    West Coast Region               1
# ..                 ...             ...
# 851  West Coast Region               1
# 852  West Coast Region               1
# 853  West Coast Region               1
# 854  West Coast Region               1
# 855  West Coast Region               1
#
# [856 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#     Area Unit                                    ANZSOC Division  Year  \
# 0      Ahaura                      Acts Intended to Cause Injury  2021
# 1      Ahaura                      Acts Intended to Cause Injury  2020
# 2      Ahaura                      Acts Intended to Cause Injury  2022
# 3      Ahaura                         Theft and Related Offences  2022
# 4      Ahaura                         Theft and Related Offences  2020
# ..        ...                                                ...   ...
# 851  Whataroa                         Theft and Related Offences  2022
# 852  Whataroa                         Theft and Related Offences  2021
# 853  Whataroa                         Theft and Related Offences  2020
# 854  Whataroa                         Theft and Related Offences  2021
# 855  Whataroa  Unlawful Entry With Intent/Burglary, Break and...  2022
#
#                 Region  Victimisations
# 0    West Coast Region               1
# 1    West Coast Region               1
# 2    West Coast Region               1
# 3    West Coast Region               2
# 4    West Coast Region               1
# ..                 ...             ...
# 851  West Coast Region               1
# 852  West Coast Region               1
# 853  West Coast Region               1
# 854  West Coast Region               1
# 855  West Coast Region               1
#
# [856 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/WestCoast.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#                Area Unit                                    ANZSOC Division  \
# 0     Greymouth Central.                      Acts Intended to Cause Injury
# 1                 Otira.                      Acts Intended to Cause Injury
# 2        Westport Urban.                      Acts Intended to Cause Injury
# 3        Hokitika Urban.                      Acts Intended to Cause Injury
# 4    Inlet-Buller River.                         Theft and Related Offences
# ..                   ...                                                ...
# 961     Greymouth South.  Unlawful Entry With Intent/Burglary, Break and...
# 962      Hokitika Rural.                         Theft and Related Offences
# 963              Karoro.                         Theft and Related Offences
# 964      Westport Urban.                         Theft and Related Offences
# 965           Blaketown.  Unlawful Entry With Intent/Burglary, Break and...
#
#      Year             Region  Victimisations
# 0    2023  West Coast Region               1
# 1    2023  West Coast Region               1
# 2    2023  West Coast Region               1
# 3    2023  West Coast Region               2
# 4    2023  West Coast Region               1
# ..    ...                ...             ...
# 961  2023  West Coast Region               1
# 962  2023  West Coast Region               1
# 963  2023  West Coast Region               1
# 964  2023  West Coast Region               1
# 965  2023  West Coast Region               1
#
# [966 rows x 5 columns]

# %%
final = pd.concat([df, df_all], ignore_index=True)
final
# Out:
#                 Area Unit                                    ANZSOC Division  \
# 0      Greymouth Central.                      Acts Intended to Cause Injury
# 1                  Otira.                      Acts Intended to Cause Injury
# 2         Westport Urban.                      Acts Intended to Cause Injury
# 3         Hokitika Urban.                      Acts Intended to Cause Injury
# 4     Inlet-Buller River.                         Theft and Related Offences
# ...                   ...                                                ...
# 1817             Whataroa                         Theft and Related Offences
# 1818             Whataroa                         Theft and Related Offences
# 1819             Whataroa                         Theft and Related Offences
# 1820             Whataroa                         Theft and Related Offences
# 1821             Whataroa  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year             Region  Victimisations
# 0     2023  West Coast Region               1
# 1     2023  West Coast Region               1
# 2     2023  West Coast Region               1
# 3     2023  West Coast Region               2
# 4     2023  West Coast Region               1
# ...    ...                ...             ...
# 1817  2022  West Coast Region               1
# 1818  2021  West Coast Region               1
# 1819  2020  West Coast Region               1
# 1820  2021  West Coast Region               1
# 1821  2022  West Coast Region               1
#
# [1822 rows x 5 columns]

# %%
final.to_csv("/Users/momoko/Desktop/NZ_Crime/Data/F_Data/Marlborough.csv")
