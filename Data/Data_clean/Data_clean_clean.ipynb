# %%
import pandas as pd
import os

# %%
os.chdir("/Users/momoko/Desktop/NZ_Crime/Data/Origin_Data")
file_chdir = os.getcwd()

csv_list = []
for root, dirs, files in os.walk(file_chdir):
    for file in files:
        if os.path.splitext(file)[1] == '.csv':
            csv_list.append(file)
            
csv_list
# Out:
# ['Manawatu.csv',
#  'Waikato.csv',
#  'Gisborne.csv',
#  'Southland.csv',
#  'Wellington.csv',
#  'Marlborough.csv',
#  'Tasman.csv',
#  'Auckland.csv',
#  'Hawke.csv',
#  'Canterbury.csv',
#  'Otago.csv',
#  'Northland.csv',
#  'Nelson.csv',
#  'WestCoast.csv',
#  'Taranaki.csv',
#  'BayofPlenty.csv']

# %%
# concat all csv to one dataframe
dfs = {}
for csv in csv_list:
    df_name = csv.split(".")[0]
    df = pd.read_csv(csv)
    dfs[df_name] = df

df = pd.concat(dfs)
df.head()
# Out:
#             Unnamed: 0                Area Unit  \
# Manawatu 0           0         Dannevirke East.
#          1           1  Norsewood-Herbertville.
#          2           2                Pahiatua.
#          3           3               Woodville.
#          4           4               Westbrook.
#
#                           ANZSOC Division  Year           Region  \
# Manawatu 0     Theft and Related Offences  2023  Manawatu Region
#          1     Theft and Related Offences  2023  Manawatu Region
#          2  Acts Intended to Cause Injury  2023  Manawatu Region
#          3  Acts Intended to Cause Injury  2023  Manawatu Region
#          4  Acts Intended to Cause Injury  2023  Manawatu Region
#
#             Victimisations
# Manawatu 0               1
#          1               1
#          2               1
#          3               1
#          4               1

# %%
# Just keep useful columns
df = df[["Area Unit", "ANZSOC Division", "Year", "Region", "Victimisations"]]
df.index = range(len(df))
df['Area Unit'] = df['Area Unit'].str.rstrip('.')
df.head()
# Out:
#                 Area Unit                ANZSOC Division  Year  \
# 0         Dannevirke East     Theft and Related Offences  2023
# 1  Norsewood-Herbertville     Theft and Related Offences  2023
# 2                Pahiatua  Acts Intended to Cause Injury  2023
# 3               Woodville  Acts Intended to Cause Injury  2023
# 4               Westbrook  Acts Intended to Cause Injury  2023
#
#             Region  Victimisations
# 0  Manawatu Region               1
# 1  Manawatu Region               1
# 2  Manawatu Region               1
# 3  Manawatu Region               1
# 4  Manawatu Region               1

# %%
df['Region'].unique()
# Out:
# array(['Manawatu Region', 'Waikato Region', 'Gisborne Region',
#        'Southland Region', 'Wellington Region', 'Marlborough Region',
#        'Tasman Region', 'Auckland Region', 'Hawke Region',
#        'Canterbury Region', 'Otago Region', 'Northland', 'Nelson Region',
#        'West Coast Region', 'Taranaki Region', 'Bay of Plenty Region'],
#       dtype=object)

# %%
df['ANZSOC Division'].unique()
# Out:
# array(['Theft and Related Offences', 'Acts Intended to Cause Injury',
#        'Unlawful Entry With Intent/Burglary, Break and Enter',
#        'Robbery, Extortion and Related Offences',
#        'Abduction, Harassment and Other Related Offences Against a Person',
#        'Sexual Assault and Related Offences'], dtype=object)

# %%
# calculate annually victimisations of each area unit
annual_area_victimisations = df.groupby(['Year', 'Area Unit'])['Victimisations'].sum().reset_index()

annual_area_victimisations['annual_area_victimisations'] = annual_area_victimisations['Victimisations']
annual_area_victimisations = annual_area_victimisations[['Year', 'Area Unit', 'annual_area_victimisations']]

annual_area_victimisations = pd.merge(df, annual_area_victimisations,on = ['Year', 'Area Unit'])
annual_area_victimisations = annual_area_victimisations[['Year', 'Area Unit', 'Region', 'annual_area_victimisations']]

annual_area_victimisations.head()
# Out:
#    Year        Area Unit           Region  annual_area_victimisations
# 0  2023  Dannevirke East  Manawatu Region                         387
# 1  2023  Dannevirke East  Manawatu Region                         387
# 2  2023  Dannevirke East  Manawatu Region                         387
# 3  2023  Dannevirke East  Manawatu Region                         387
# 4  2023  Dannevirke East  Manawatu Region                         387

# %%
# Calculate annual victimisations of each area unit by crime types
annual_area_victimisations_by_types = df.groupby(['Area Unit', 'ANZSOC Division', 'Year'])['Victimisations'].sum().reset_index()

annual_area_victimisations_by_types['annual_area_victimisations_by_types'] = annual_area_victimisations_by_types['Victimisations']
annual_area_victimisations_by_types = annual_area_victimisations_by_types[['Area Unit', 'ANZSOC Division', 'Year', 'annual_area_victimisations_by_types']]

annual_area_victimisations_by_types.head()
# Out:
#      Area Unit                          ANZSOC Division  Year  \
# 0  Abbey Caves            Acts Intended to Cause Injury  2020
# 1  Abbey Caves  Robbery, Extortion and Related Offences  2022
# 2  Abbey Caves               Theft and Related Offences  2020
# 3  Abbey Caves               Theft and Related Offences  2021
# 4  Abbey Caves               Theft and Related Offences  2022
#
#    annual_area_victimisations_by_types
# 0                                    2
# 1                                    1
# 2                                   17
# 3                                    2
# 4                                    1

# %%
df_pivot = annual_area_victimisations_by_types.pivot_table(
    index=['Area Unit', 'Year'],  
    columns='ANZSOC Division',  
    values='annual_area_victimisations_by_types',  
    fill_value=0  
).reset_index()

df_pivot
# Out:
# ANZSOC Division    Area Unit  Year  \
# 0                Abbey Caves  2020
# 1                Abbey Caves  2021
# 2                Abbey Caves  2022
# 3                Abbey Caves  2023
# 4                 Abbotsford  2020
# ...                      ...   ...
# 7432               Yaldhurst  2023
# 7433             Yatton Park  2020
# 7434             Yatton Park  2021
# 7435             Yatton Park  2022
# 7436             Yatton Park  2023
#
# ANZSOC Division  Abduction, Harassment and Other Related Offences Against a Person  \
# 0                                                                0
# 1                                                                0
# 2                                                                0
# 3                                                                0
# 4                                                                0
# ...                                                            ...
# 7432                                                             0
# 7433                                                             0
# 7434                                                             0
# 7435                                                             0
# 7436                                                             0
#
# ANZSOC Division  Acts Intended to Cause Injury  \
# 0                                            2
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            1
# ...                                        ...
# 7432                                        13
# 7433                                        23
# 7434                                        19
# 7435                                        17
# 7436                                        20
#
# ANZSOC Division  Robbery, Extortion and Related Offences  \
# 0                                                      0
# 1                                                      0
# 2                                                      1
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 7432                                                   0
# 7433                                                   1
# 7434                                                   1
# 7435                                                   2
# 7436                                                   2
#
# ANZSOC Division  Sexual Assault and Related Offences  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 7432                                               6
# 7433                                               0
# 7434                                               0
# 7435                                               0
# 7436                                               1
#
# ANZSOC Division  Theft and Related Offences  \
# 0                                        17
# 1                                         2
# 2                                         1
# 3                                         6
# 4                                         1
# ...                                     ...
# 7432                                    459
# 7433                                     13
# 7434                                     18
# 7435                                     23
# 7436                                     48
#
# ANZSOC Division  Unlawful Entry With Intent/Burglary, Break and Enter
# 0                                                                0
# 1                                                                0
# 2                                                                0
# 3                                                                4
# 4                                                                1
# ...                                                            ...
# 7432                                                            79
# 7433                                                            10
# 7434                                                            10
# 7435                                                            10
# 7436                                                            33
#
# [7437 rows x 8 columns]

# %%
# dictionary
new_column_names = {
    'Area Unit': 'Area Unit',  
    'Year': 'Year', 
    'Abduction, Harassment and Other Related Offences Against a Person': 'Abduction_Harassment_Related',
    'Acts Intended to Cause Injury': 'Acts_Intended_to_Cause_Injury',
    'Robbery, Extortion and Related Offences': 'Robbery_Extortion_Related',
    'Sexual Assault and Related Offences': 'Sexual_Assault_Related',
    'Theft and Related Offences': 'Theft_Related',
    'Unlawful Entry With Intent/Burglary, Break and Enter': 'Unlawful_Entry_With_Intent',
}

# rename columns' name
df_pivot_renamed = df_pivot.rename(columns=new_column_names)

df_pivot_renamed.head()
# Out:
# ANZSOC Division    Area Unit  Year  Abduction_Harassment_Related  \
# 0                Abbey Caves  2020                             0
# 1                Abbey Caves  2021                             0
# 2                Abbey Caves  2022                             0
# 3                Abbey Caves  2023                             0
# 4                 Abbotsford  2020                             0
#
# ANZSOC Division  Acts_Intended_to_Cause_Injury  Robbery_Extortion_Related  \
# 0                                            2                          0
# 1                                            0                          0
# 2                                            0                          1
# 3                                            0                          0
# 4                                            1                          0
#
# ANZSOC Division  Sexual_Assault_Related  Theft_Related  \
# 0                                     0             17
# 1                                     0              2
# 2                                     0              1
# 3                                     0              6
# 4                                     0              1
#
# ANZSOC Division  Unlawful_Entry_With_Intent
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         4
# 4                                         1

# %%
area_unit = pd.merge(annual_area_victimisations, df_pivot_renamed, on = ['Area Unit', 'Year'])
area_unit.head()
# Out:
#    Year        Area Unit           Region  annual_area_victimisations  \
# 0  2023  Dannevirke East  Manawatu Region                         387
# 1  2023  Dannevirke East  Manawatu Region                         387
# 2  2023  Dannevirke East  Manawatu Region                         387
# 3  2023  Dannevirke East  Manawatu Region                         387
# 4  2023  Dannevirke East  Manawatu Region                         387
#
#    Abduction_Harassment_Related  Acts_Intended_to_Cause_Injury  \
# 0                             0                             35
# 1                             0                             35
# 2                             0                             35
# 3                             0                             35
# 4                             0                             35
#
#    Robbery_Extortion_Related  Sexual_Assault_Related  Theft_Related  \
# 0                          4                       6            295
# 1                          4                       6            295
# 2                          4                       6            295
# 3                          4                       6            295
# 4                          4                       6            295
#
#    Unlawful_Entry_With_Intent
# 0                          47
# 1                          47
# 2                          47
# 3                          47
# 4                          47

# %%
# Read geo data of area unit
area_unit_geo_data = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/GeoData/statsnz-area-unit-2013-CSV/area-unit-2013.csv")
area_unit_geo_data.rename(columns = {'AU2013_V1_00_NAME':'Area Unit'}, inplace = True)
area_unit_geo_data.head()
# Out:
#                                                  WKT  AU2013_V1_00  \
# 0  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
# 1  MULTIPOLYGON (((1648130.4696 6128680.4221,1648...        500203
# 2  MULTIPOLYGON (((1622142.1514 6120287.4396,1623...        500204
# 3  MULTIPOLYGON (((1615173.0158 6110225.8463,1615...        500205
# 4  MULTIPOLYGON (((1601317.2322 6194284.5759,1601...        500206
#
#                           Area Unit  AREA_SQ_KM  LAND_AREA_SQ_KM  \
# 0  Karikari Peninsula-Maungataniwha  791.188485       784.395200
# 1                Taipa Bay-Mangonui    5.545054         5.545054
# 2                          Herekino  396.511344       391.067273
# 3                           Ahipara    8.000104         8.000104
# 4                        North Cape  690.237222       626.035844
#
#     Shape_Length
# 0  285586.495714
# 1   25711.852169
# 2  172051.055675
# 3   20638.880335
# 4  177953.473387

# %%
# merge victimisation data and geo data 
area_unit = pd.merge(area_unit_geo_data, area_unit, on = 'Area Unit')
area_unit.head()
# Out:
#                                                  WKT  AU2013_V1_00  \
# 0  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
# 1  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
# 2  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
# 3  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
# 4  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...        500202
#
#                           Area Unit  AREA_SQ_KM  LAND_AREA_SQ_KM  \
# 0  Karikari Peninsula-Maungataniwha  791.188485         784.3952
# 1  Karikari Peninsula-Maungataniwha  791.188485         784.3952
# 2  Karikari Peninsula-Maungataniwha  791.188485         784.3952
# 3  Karikari Peninsula-Maungataniwha  791.188485         784.3952
# 4  Karikari Peninsula-Maungataniwha  791.188485         784.3952
#
#     Shape_Length  Year     Region  annual_area_victimisations  \
# 0  285586.495714  2023  Northland                         137
# 1  285586.495714  2023  Northland                         137
# 2  285586.495714  2023  Northland                         137
# 3  285586.495714  2023  Northland                         137
# 4  285586.495714  2023  Northland                         137
#
#    Abduction_Harassment_Related  Acts_Intended_to_Cause_Injury  \
# 0                             0                             14
# 1                             0                             14
# 2                             0                             14
# 3                             0                             14
# 4                             0                             14
#
#    Robbery_Extortion_Related  Sexual_Assault_Related  Theft_Related  \
# 0                          1                       2             40
# 1                          1                       2             40
# 2                          1                       2             40
# 3                          1                       2             40
# 4                          1                       2             40
#
#    Unlawful_Entry_With_Intent
# 0                          80
# 1                          80
# 2                          80
# 3                          80
# 4                          80

# %%
print(area_unit.columns)
# Out:
# Index(['WKT', 'AU2013_V1_00', 'Area Unit', 'AREA_SQ_KM', 'LAND_AREA_SQ_KM',
#        'Shape_Length', 'Year', 'Region', 'annual_area_victimisations',
#        'Abduction_Harassment_Related', 'Acts_Intended_to_Cause_Injury',
#        'Robbery_Extortion_Related', 'Sexual_Assault_Related', 'Theft_Related',
#        'Unlawful_Entry_With_Intent'],
#       dtype='object')

# %%
area_unit = area_unit[['WKT', 'Area Unit', 'AREA_SQ_KM', 'LAND_AREA_SQ_KM', 'Shape_Length', 'Region', 'annual_area_victimisations', 'Abduction_Harassment_Related', 'Acts_Intended_to_Cause_Injury', 'Robbery_Extortion_Related', 'Sexual_Assault_Related', 'Theft_Related', 'Unlawful_Entry_With_Intent', 'Year']]

area_unit = area_unit.drop_duplicates()

area_unit['Year'] = area_unit['Year'].astype(int)
area_unit['annual_area_victimisations'] = area_unit['annual_area_victimisations'].astype(int)
area_unit['Abduction_Harassment_Related'] = area_unit['Abduction_Harassment_Related'].astype(int)
area_unit['Acts_Intended_to_Cause_Injury'] = area_unit['Acts_Intended_to_Cause_Injury'].astype(int)
area_unit['Robbery_Extortion_Related'] = area_unit['Robbery_Extortion_Related'].astype(int)
area_unit['Sexual_Assault_Related'] = area_unit['Sexual_Assault_Related'].astype(int)
area_unit['Theft_Related'] = area_unit['Theft_Related'].astype(int)
area_unit['Unlawful_Entry_With_Intent'] = area_unit['Unlawful_Entry_With_Intent'].astype(int)

area_unit.head()
# Out:
#                                                    WKT  \
# 0    MULTIPOLYGON (((1636527.0069 6150940.0624,1636...
# 132  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...
# 168  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...
# 200  MULTIPOLYGON (((1636527.0069 6150940.0624,1636...
# 234  MULTIPOLYGON (((1648130.4696 6128680.4221,1648...
#
#                             Area Unit  AREA_SQ_KM  LAND_AREA_SQ_KM  \
# 0    Karikari Peninsula-Maungataniwha  791.188485       784.395200
# 132  Karikari Peninsula-Maungataniwha  791.188485       784.395200
# 168  Karikari Peninsula-Maungataniwha  791.188485       784.395200
# 200  Karikari Peninsula-Maungataniwha  791.188485       784.395200
# 234                Taipa Bay-Mangonui    5.545054         5.545054
#
#       Shape_Length     Region  annual_area_victimisations  \
# 0    285586.495714  Northland                         137
# 132  285586.495714  Northland                          70
# 168  285586.495714  Northland                          77
# 200  285586.495714  Northland                          64
# 234   25711.852169  Northland                         207
#
#      Abduction_Harassment_Related  Acts_Intended_to_Cause_Injury  \
# 0                               0                             14
# 132                             1                             19
# 168                             1                             14
# 200                             0                             16
# 234                             0                             19
#
#      Robbery_Extortion_Related  Sexual_Assault_Related  Theft_Related  \
# 0                            1                       2             40
# 132                          0                       1             19
# 168                          0                       1             33
# 200                          0                       3             21
# 234                          1                       0            131
#
#      Unlawful_Entry_With_Intent  Year
# 0                            80  2023
# 132                          30  2020
# 168                          28  2022
# 200                          24  2021
# 234                          56  2023

# %%
# Save date of area unit as a csv file
area_unit.to_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Final_area_unit.csv")

# %%
# Calculate anuual crime data of each region by crime types
annual_region_victimisations_by_types = df.groupby(['Region', 'ANZSOC Division', 'Year'])['Victimisations'].sum().reset_index()

annual_region_victimisations_by_types['annual_region_victimisations_by_types'] = annual_region_victimisations_by_types['Victimisations']
annual_region_victimisations_by_types = annual_region_victimisations_by_types[['Region','ANZSOC Division','Year','annual_region_victimisations_by_types']]

annual_region_victimisations_by_types.head()
# Out:
#             Region                                    ANZSOC Division  Year  \
# 0  Auckland Region  Abduction, Harassment and Other Related Offenc...  2020
# 1  Auckland Region  Abduction, Harassment and Other Related Offenc...  2021
# 2  Auckland Region  Abduction, Harassment and Other Related Offenc...  2022
# 3  Auckland Region  Abduction, Harassment and Other Related Offenc...  2023
# 4  Auckland Region                      Acts Intended to Cause Injury  2020
#
#    annual_region_victimisations_by_types
# 0                                     46
# 1                                     80
# 2                                     52
# 3                                     70
# 4                                   6064

# %%
region_pivot = annual_region_victimisations_by_types.pivot_table(
    index=['Region', 'Year'],  
    columns='ANZSOC Division',  
    values='annual_region_victimisations_by_types',  
    fill_value=0  
).reset_index()

region_pivot
# Out:
# ANZSOC Division                Region  Year  \
# 0                     Auckland Region  2020
# 1                     Auckland Region  2021
# 2                     Auckland Region  2022
# 3                     Auckland Region  2023
# 4                Bay of Plenty Region  2020
# ..                                ...   ...
# 59                  Wellington Region  2023
# 60                  West Coast Region  2020
# 61                  West Coast Region  2021
# 62                  West Coast Region  2022
# 63                  West Coast Region  2023
#
# ANZSOC Division  Abduction, Harassment and Other Related Offences Against a Person  \
# 0                                                               46
# 1                                                               80
# 2                                                               52
# 3                                                               70
# 4                                                               11
# ..                                                             ...
# 59                                                              14
# 60                                                               0
# 61                                                               1
# 62                                                               0
# 63                                                               1
#
# ANZSOC Division  Acts Intended to Cause Injury  \
# 0                                         6064
# 1                                        13696
# 2                                         8034
# 3                                         9778
# 4                                         1851
# ..                                         ...
# 59                                        3218
# 60                                         142
# 61                                         152
# 62                                         158
# 63                                         166
#
# ANZSOC Division  Robbery, Extortion and Related Offences  \
# 0                                                    834
# 1                                                   1785
# 2                                                   1186
# 3                                                   1794
# 4                                                    141
# ..                                                   ...
# 59                                                   470
# 60                                                     4
# 61                                                     0
# 62                                                    10
# 63                                                    16
#
# ANZSOC Division  Sexual Assault and Related Offences  \
# 0                                                366
# 1                                                852
# 2                                                468
# 3                                                741
# 4                                                 66
# ..                                               ...
# 59                                               264
# 60                                                 9
# 61                                                33
# 62                                                22
# 63                                                29
#
# ANZSOC Division  Theft and Related Offences  \
# 0                                     28377
# 1                                     32423
# 2                                     45747
# 3                                     82877
# 4                                      7707
# ..                                      ...
# 59                                    21188
# 60                                      300
# 61                                      178
# 62                                      264
# 63                                      498
#
# ANZSOC Division  Unlawful Entry With Intent/Burglary, Break and Enter
# 0                                                             6027
# 1                                                            13722
# 2                                                             9299
# 3                                                            21322
# 4                                                             1185
# ..                                                             ...
# 59                                                            5627
# 60                                                             108
# 61                                                              72
# 62                                                             106
# 63                                                             303
#
# [64 rows x 8 columns]

# %%
# dictionary
new_columns = {
    'Region': 'Region',  
    'Year': 'Year', 
    'Abduction, Harassment and Other Related Offences Against a Person': 'Abduction_Harassment_Related',
    'Acts Intended to Cause Injury': 'Acts_Intended_to_Cause_Injury',
    'Robbery, Extortion and Related Offences': 'Robbery_Extortion_Related',
    'Sexual Assault and Related Offences': 'Sexual_Assault_Related',
    'Theft and Related Offences': 'Theft_Related',
    'Unlawful Entry With Intent/Burglary, Break and Enter': 'Unlawful_Entry_With_Intent',
}

# rename columns' name
region_pivot_renamed = region_pivot.rename(columns=new_columns)

region_pivot_renamed.head()
# Out:
# ANZSOC Division                Region  Year  Abduction_Harassment_Related  \
# 0                     Auckland Region  2020                            46
# 1                     Auckland Region  2021                            80
# 2                     Auckland Region  2022                            52
# 3                     Auckland Region  2023                            70
# 4                Bay of Plenty Region  2020                            11
#
# ANZSOC Division  Acts_Intended_to_Cause_Injury  Robbery_Extortion_Related  \
# 0                                         6064                        834
# 1                                        13696                       1785
# 2                                         8034                       1186
# 3                                         9778                       1794
# 4                                         1851                        141
#
# ANZSOC Division  Sexual_Assault_Related  Theft_Related  \
# 0                                   366          28377
# 1                                   852          32423
# 2                                   468          45747
# 3                                   741          82877
# 4                                    66           7707
#
# ANZSOC Division  Unlawful_Entry_With_Intent
# 0                                      6027
# 1                                     13722
# 2                                      9299
# 3                                     21322
# 4                                      1185

# %%
# Calculate anuual crime data of each region
annual_region_victimisations = df.groupby(['Region', 'Year'])['Victimisations'].sum().reset_index()

annual_region_victimisations['annual_region_victimisations'] = annual_region_victimisations['Victimisations']
annual_region_victimisations = annual_region_victimisations[['Region','Year','annual_region_victimisations']]

region = pd.merge(region_pivot_renamed, annual_region_victimisations, on = ['Region', 'Year'])
region.head()
# Out:
#                  Region  Year  Abduction_Harassment_Related  \
# 0       Auckland Region  2020                            46
# 1       Auckland Region  2021                            80
# 2       Auckland Region  2022                            52
# 3       Auckland Region  2023                            70
# 4  Bay of Plenty Region  2020                            11
#
#    Acts_Intended_to_Cause_Injury  Robbery_Extortion_Related  \
# 0                           6064                        834
# 1                          13696                       1785
# 2                           8034                       1186
# 3                           9778                       1794
# 4                           1851                        141
#
#    Sexual_Assault_Related  Theft_Related  Unlawful_Entry_With_Intent  \
# 0                     366          28377                        6027
# 1                     852          32423                       13722
# 2                     468          45747                        9299
# 3                     741          82877                       21322
# 4                      66           7707                        1185
#
#    annual_region_victimisations
# 0                         41714
# 1                         62558
# 2                         64786
# 3                        116582
# 4                         10961

# %%
# Read geo data of regions
region_geo_data = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/GeoData/statsnz-regional-council-2023-generalised-CSV/regional-council-2023-generalised.csv")
region_geo_data.rename(columns = {'REGC2023_V1_00_NAME':'Region'}, inplace = True)
region_geo_data.head()
# Out:
#                                                  WKT  REGC2023_V1_00  \
# 0  MULTIPOLYGON (((1611941.3123 6214121.2253,1613...               1
# 1  MULTIPOLYGON (((1788533.2652 6047342.7999,1789...               2
# 2  MULTIPOLYGON (((1871103.9568 5970628.8849,1871...               3
# 3  MULTIPOLYGON (((1911825.0341 5859943.0545,1912...               4
# 4  MULTIPOLYGON (((2063779.7816 5855283.2052,2064...               5
#
#                  Region REGC2023_V1_00_NAME_ASCII  LAND_AREA_SQ_KM  \
# 0      Northland Region          Northland Region     12507.139052
# 1       Auckland Region           Auckland Region      4941.164248
# 2        Waikato Region            Waikato Region     23900.953428
# 3  Bay of Plenty Region      Bay of Plenty Region     12071.549623
# 4       Gisborne Region           Gisborne Region      8385.064982
#
#      AREA_SQ_KM  Shape_Length
# 0  30084.273236  8.113598e+05
# 1  16156.206271  6.609735e+05
# 2  34888.831710  1.268420e+06
# 3  21883.742229  1.093737e+06
# 4  13989.056001  6.959185e+05

# %%
region_geo_data['Region'].unique()
# Out:
# array(['Northland Region', 'Auckland Region', 'Waikato Region',
#        'Bay of Plenty Region', 'Gisborne Region', "Hawke's Bay Region",
#        'Taranaki Region', 'Manawatū-Whanganui Region',
#        'Wellington Region', 'West Coast Region', 'Canterbury Region',
#        'Otago Region', 'Southland Region', 'Tasman Region',
#        'Nelson Region', 'Marlborough Region', 'Area Outside Region'],
#       dtype=object)

# %%
region_geo_data['Region'] = region_geo_data['Region'].replace('Manawatū-Whanganui Region', 'Manawatu Region')
region_geo_data['Region'] = region_geo_data['Region'].replace("Hawke's Bay Region", "Hawke Region")
region_geo_data['Region'] = region_geo_data['Region'].replace('Northland Region', 'Northland')
region_geo_data['Region'].unique()
# Out:
# array(['Northland', 'Auckland Region', 'Waikato Region',
#        'Bay of Plenty Region', 'Gisborne Region', 'Hawke Region',
#        'Taranaki Region', 'Manawatu Region', 'Wellington Region',
#        'West Coast Region', 'Canterbury Region', 'Otago Region',
#        'Southland Region', 'Tasman Region', 'Nelson Region',
#        'Marlborough Region', 'Area Outside Region'], dtype=object)

# %%
region['Region'].unique()
# Out:
# array(['Auckland Region', 'Bay of Plenty Region', 'Canterbury Region',
#        'Gisborne Region', 'Hawke Region', 'Manawatu Region',
#        'Marlborough Region', 'Nelson Region', 'Northland', 'Otago Region',
#        'Southland Region', 'Taranaki Region', 'Tasman Region',
#        'Waikato Region', 'Wellington Region', 'West Coast Region'],
#       dtype=object)

# %%
# merge victimisation data and geo data 
region = pd.merge(region, region_geo_data, on = 'Region')
region
# Out:
#                   Region  Year  Abduction_Harassment_Related  \
# 0        Auckland Region  2020                            46
# 1        Auckland Region  2021                            80
# 2        Auckland Region  2022                            52
# 3        Auckland Region  2023                            70
# 4   Bay of Plenty Region  2020                            11
# ..                   ...   ...                           ...
# 59     Wellington Region  2023                            14
# 60     West Coast Region  2020                             0
# 61     West Coast Region  2021                             1
# 62     West Coast Region  2022                             0
# 63     West Coast Region  2023                             1
#
#     Acts_Intended_to_Cause_Injury  Robbery_Extortion_Related  \
# 0                            6064                        834
# 1                           13696                       1785
# 2                            8034                       1186
# 3                            9778                       1794
# 4                            1851                        141
# ..                            ...                        ...
# 59                           3218                        470
# 60                            142                          4
# 61                            152                          0
# 62                            158                         10
# 63                            166                         16
#
#     Sexual_Assault_Related  Theft_Related  Unlawful_Entry_With_Intent  \
# 0                      366          28377                        6027
# 1                      852          32423                       13722
# 2                      468          45747                        9299
# 3                      741          82877                       21322
# 4                       66           7707                        1185
# ..                     ...            ...                         ...
# 59                     264          21188                        5627
# 60                       9            300                         108
# 61                      33            178                          72
# 62                      22            264                         106
# 63                      29            498                         303
#
#     annual_region_victimisations  \
# 0                          41714
# 1                          62558
# 2                          64786
# 3                         116582
# 4                          10961
# ..                           ...
# 59                         30781
# 60                           563
# 61                           436
# 62                           560
# 63                          1013
#
#                                                   WKT  REGC2023_V1_00  \
# 0   MULTIPOLYGON (((1788533.2652 6047342.7999,1789...               2
# 1   MULTIPOLYGON (((1788533.2652 6047342.7999,1789...               2
# 2   MULTIPOLYGON (((1788533.2652 6047342.7999,1789...               2
# 3   MULTIPOLYGON (((1788533.2652 6047342.7999,1789...               2
# 4   MULTIPOLYGON (((1911825.0341 5859943.0545,1912...               4
# ..                                                ...             ...
# 59  MULTIPOLYGON (((1783549.0901 5490093.7101,1783...               9
# 60  MULTIPOLYGON (((1536071.5819 5480250.3799,1536...              12
# 61  MULTIPOLYGON (((1536071.5819 5480250.3799,1536...              12
# 62  MULTIPOLYGON (((1536071.5819 5480250.3799,1536...              12
# 63  MULTIPOLYGON (((1536071.5819 5480250.3799,1536...              12
#
#    REGC2023_V1_00_NAME_ASCII  LAND_AREA_SQ_KM    AREA_SQ_KM  Shape_Length
# 0            Auckland Region      4941.164248  16156.206271  6.609735e+05
# 1            Auckland Region      4941.164248  16156.206271  6.609735e+05
# 2            Auckland Region      4941.164248  16156.206271  6.609735e+05
# 3            Auckland Region      4941.164248  16156.206271  6.609735e+05
# 4       Bay of Plenty Region     12071.549623  21883.742229  1.093737e+06
# ..                       ...              ...           ...           ...
# 59         Wellington Region      8049.474240  15945.317606  5.791960e+05
# 60         West Coast Region     23245.518393  36339.584151  1.582117e+06
# 61         West Coast Region     23245.518393  36339.584151  1.582117e+06
# 62         West Coast Region     23245.518393  36339.584151  1.582117e+06
# 63         West Coast Region     23245.518393  36339.584151  1.582117e+06
#
# [64 rows x 15 columns]

# %%
region['Region'].unique()
# Out:
# array(['Auckland Region', 'Bay of Plenty Region', 'Canterbury Region',
#        'Gisborne Region', 'Hawke Region', 'Manawatu Region',
#        'Marlborough Region', 'Nelson Region', 'Northland', 'Otago Region',
#        'Southland Region', 'Taranaki Region', 'Tasman Region',
#        'Waikato Region', 'Wellington Region', 'West Coast Region'],
#       dtype=object)

# %%
region = region[['WKT', 'Region', 'LAND_AREA_SQ_KM', 'AREA_SQ_KM', 'Shape_Length', 'annual_region_victimisations', 'Abduction_Harassment_Related', 'Acts_Intended_to_Cause_Injury', 'Robbery_Extortion_Related', 'Sexual_Assault_Related', 'Theft_Related', 'Unlawful_Entry_With_Intent','Year']]

region = region.drop_duplicates()

region['Year'] = region['Year'].astype(int)
region['annual_region_victimisations'] = region['annual_region_victimisations'].astype(int)
region['Abduction_Harassment_Related'] = region['Abduction_Harassment_Related'].astype(int)
region['Acts_Intended_to_Cause_Injury'] = region['Acts_Intended_to_Cause_Injury'].astype(int)
region['Robbery_Extortion_Related'] = region['Robbery_Extortion_Related'].astype(int)
region['Sexual_Assault_Related'] = region['Sexual_Assault_Related'].astype(int)
region['Theft_Related'] = region['Theft_Related'].astype(int)
region['Unlawful_Entry_With_Intent'] = region['Unlawful_Entry_With_Intent'].astype(int)
region.head()
# Out:
#                                                  WKT                Region  \
# 0  MULTIPOLYGON (((1788533.2652 6047342.7999,1789...       Auckland Region
# 1  MULTIPOLYGON (((1788533.2652 6047342.7999,1789...       Auckland Region
# 2  MULTIPOLYGON (((1788533.2652 6047342.7999,1789...       Auckland Region
# 3  MULTIPOLYGON (((1788533.2652 6047342.7999,1789...       Auckland Region
# 4  MULTIPOLYGON (((1911825.0341 5859943.0545,1912...  Bay of Plenty Region
#
#    LAND_AREA_SQ_KM    AREA_SQ_KM  Shape_Length  annual_region_victimisations  \
# 0      4941.164248  16156.206271  6.609735e+05                         41714
# 1      4941.164248  16156.206271  6.609735e+05                         62558
# 2      4941.164248  16156.206271  6.609735e+05                         64786
# 3      4941.164248  16156.206271  6.609735e+05                        116582
# 4     12071.549623  21883.742229  1.093737e+06                         10961
#
#    Abduction_Harassment_Related  Acts_Intended_to_Cause_Injury  \
# 0                            46                           6064
# 1                            80                          13696
# 2                            52                           8034
# 3                            70                           9778
# 4                            11                           1851
#
#    Robbery_Extortion_Related  Sexual_Assault_Related  Theft_Related  \
# 0                        834                     366          28377
# 1                       1785                     852          32423
# 2                       1186                     468          45747
# 3                       1794                     741          82877
# 4                        141                      66           7707
#
#    Unlawful_Entry_With_Intent  Year
# 0                        6027  2020
# 1                       13722  2021
# 2                        9299  2022
# 3                       21322  2023
# 4                        1185  2020

# %%
# Save date of region as a csv file
region.to_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Final_region.csv")
