# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Otago.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#              Area Unit                                    ANZSOC Division  \
# 0           Abbotsford                      Acts Intended to Cause Injury
# 1           Abbotsford                      Acts Intended to Cause Injury
# 2           Abbotsford                      Acts Intended to Cause Injury
# 3           Abbotsford                Sexual Assault and Related Offences
# 4           Abbotsford                Sexual Assault and Related Offences
# ...                ...                                                ...
# 4241  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4242  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4243  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4244  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4245  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year Month        Region  Victimisations
# 0     2021-02-01  Otago Region               1
# 1     2021-10-01  Otago Region               1
# 2     2020-11-01  Otago Region               1
# 3     2021-07-01  Otago Region               1
# 4     2022-09-01  Otago Region               1
# ...          ...           ...             ...
# 4241  2020-02-01  Otago Region               1
# 4242  2022-02-01  Otago Region               1
# 4243  2021-07-01  Otago Region               1
# 4244  2020-10-01  Otago Region               1
# 4245  2021-12-01  Otago Region               1
#
# [4246 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#              Area Unit                                    ANZSOC Division  \
# 0           Abbotsford                      Acts Intended to Cause Injury
# 1           Abbotsford                      Acts Intended to Cause Injury
# 2           Abbotsford                      Acts Intended to Cause Injury
# 3           Abbotsford                Sexual Assault and Related Offences
# 4           Abbotsford                Sexual Assault and Related Offences
# ...                ...                                                ...
# 4241  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4242  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4243  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4244  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
# 4245  Wyllies Crossing  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year        Region  Victimisations
# 0     2021  Otago Region               1
# 1     2021  Otago Region               1
# 2     2020  Otago Region               1
# 3     2021  Otago Region               1
# 4     2022  Otago Region               1
# ...    ...           ...             ...
# 4241  2020  Otago Region               1
# 4242  2022  Otago Region               1
# 4243  2021  Otago Region               1
# 4244  2020  Otago Region               1
# 4245  2021  Otago Region               1
#
# [4246 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Otago.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#                     Area Unit  \
# 0              St Kilda West.
# 1     Stuart St-Frederick St.
# 2                  Caversham.
# 3                    Kenmure.
# 4                 Waikouaiti.
# ...                       ...
# 6863                Frankton.
# 6864          Queenstown Bay.
# 6865          Queenstown Bay.
# 6866         Queenstown Hill.
# 6867           Frankton East.
#
#                                         ANZSOC Division  Year        Region  \
# 0                            Theft and Related Offences  2023  Otago Region
# 1                            Theft and Related Offences  2023  Otago Region
# 2                            Theft and Related Offences  2023  Otago Region
# 3                            Theft and Related Offences  2023  Otago Region
# 4                            Theft and Related Offences  2023  Otago Region
# ...                                                 ...   ...           ...
# 6863  Unlawful Entry With Intent/Burglary, Break and...  2023  Otago Region
# 6864                      Acts Intended to Cause Injury  2023  Otago Region
# 6865                      Acts Intended to Cause Injury  2023  Otago Region
# 6866                         Theft and Related Offences  2023  Otago Region
# 6867                         Theft and Related Offences  2023  Otago Region
#
#       Victimisations
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 6863               1
# 6864               1
# 6865               1
# 6866               1
# 6867               1
#
# [6868 rows x 5 columns]

# %%
final = pd.concat([df, df_all], ignore_index=True)
final
# Out:
#                      Area Unit  \
# 0               St Kilda West.
# 1      Stuart St-Frederick St.
# 2                   Caversham.
# 3                     Kenmure.
# 4                  Waikouaiti.
# ...                        ...
# 11109         Wyllies Crossing
# 11110         Wyllies Crossing
# 11111         Wyllies Crossing
# 11112         Wyllies Crossing
# 11113         Wyllies Crossing
#
#                                          ANZSOC Division  Year        Region  \
# 0                             Theft and Related Offences  2023  Otago Region
# 1                             Theft and Related Offences  2023  Otago Region
# 2                             Theft and Related Offences  2023  Otago Region
# 3                             Theft and Related Offences  2023  Otago Region
# 4                             Theft and Related Offences  2023  Otago Region
# ...                                                  ...   ...           ...
# 11109  Unlawful Entry With Intent/Burglary, Break and...  2020  Otago Region
# 11110  Unlawful Entry With Intent/Burglary, Break and...  2022  Otago Region
# 11111  Unlawful Entry With Intent/Burglary, Break and...  2021  Otago Region
# 11112  Unlawful Entry With Intent/Burglary, Break and...  2020  Otago Region
# 11113  Unlawful Entry With Intent/Burglary, Break and...  2021  Otago Region
#
#        Victimisations
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 11109               1
# 11110               1
# 11111               1
# 11112               1
# 11113               1
#
# [11114 rows x 5 columns]
