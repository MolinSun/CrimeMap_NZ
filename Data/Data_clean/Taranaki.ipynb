# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Taranaki.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#        Area Unit                                    ANZSOC Division  \
# 0        Barrett                      Acts Intended to Cause Injury
# 1        Barrett                      Acts Intended to Cause Injury
# 2        Barrett                      Acts Intended to Cause Injury
# 3        Barrett            Robbery, Extortion and Related Offences
# 4        Barrett                Sexual Assault and Related Offences
# ...          ...                                                ...
# 2890  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...
# 2891  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...
# 2892  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...
# 2893  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...
# 2894  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...
#
#       Year Month           Region  Victimisations
# 0     2021-06-01  Taranaki Region               2
# 1     2021-07-01  Taranaki Region               1
# 2     2020-11-01  Taranaki Region               2
# 3     2022-11-01  Taranaki Region               2
# 4     2020-08-01  Taranaki Region               1
# ...          ...              ...             ...
# 2890  2021-06-01  Taranaki Region               1
# 2891  2022-07-01  Taranaki Region               1
# 2892  2022-08-01  Taranaki Region               1
# 2893  2022-10-01  Taranaki Region               1
# 2894  2021-12-01  Taranaki Region               1
#
# [2895 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#        Area Unit                                    ANZSOC Division  Year  \
# 0        Barrett                      Acts Intended to Cause Injury  2021
# 1        Barrett                      Acts Intended to Cause Injury  2021
# 2        Barrett                      Acts Intended to Cause Injury  2020
# 3        Barrett            Robbery, Extortion and Related Offences  2022
# 4        Barrett                Sexual Assault and Related Offences  2020
# ...          ...                                                ...   ...
# 2890  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...  2021
# 2891  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...  2022
# 2892  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...  2022
# 2893  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...  2022
# 2894  Whenuakura  Unlawful Entry With Intent/Burglary, Break and...  2021
#
#                Region  Victimisations
# 0     Taranaki Region               2
# 1     Taranaki Region               1
# 2     Taranaki Region               2
# 3     Taranaki Region               2
# 4     Taranaki Region               1
# ...               ...             ...
# 2890  Taranaki Region               1
# 2891  Taranaki Region               1
# 2892  Taranaki Region               1
# 2893  Taranaki Region               1
# 2894  Taranaki Region               1
#
# [2895 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Taranaki.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#                   Area Unit  \
# 0                  Moturoa.
# 1              Mount Bryan.
# 2     New Plymouth Central.
# 3                  Barrett.
# 4                Glen Avon.
# ...                     ...
# 4822          Hawera North.
# 4823                Manaia.
# 4824          Waitara West.
# 4825               Kawaroa.
# 4826          Hawera North.
#
#                                         ANZSOC Division  Year  \
# 0                            Theft and Related Offences  2023
# 1                            Theft and Related Offences  2023
# 2                            Theft and Related Offences  2023
# 3     Unlawful Entry With Intent/Burglary, Break and...  2023
# 4                            Theft and Related Offences  2023
# ...                                                 ...   ...
# 4822  Unlawful Entry With Intent/Burglary, Break and...  2023
# 4823  Unlawful Entry With Intent/Burglary, Break and...  2023
# 4824                      Acts Intended to Cause Injury  2023
# 4825                         Theft and Related Offences  2023
# 4826                         Theft and Related Offences  2023
#
#                Region  Victimisations
# 0     Taranaki Region               1
# 1     Taranaki Region               1
# 2     Taranaki Region               1
# 3     Taranaki Region               1
# 4     Taranaki Region               1
# ...               ...             ...
# 4822  Taranaki Region               1
# 4823  Taranaki Region               1
# 4824  Taranaki Region               1
# 4825  Taranaki Region               1
# 4826  Taranaki Region               1
#
# [4827 rows x 5 columns]
