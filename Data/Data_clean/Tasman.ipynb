# %%
import pandas as pd
import os

# %%
df_all = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/Final_Data/Tasman.csv")
df_all = df_all[~df_all['Year Month'].str.contains('2023')]
df_all = df_all[~df_all['Year Month'].str.contains('2019')]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year Month", "Region","Victimisations"]]
df_all.index = range(len(df_all))
df_all
# Out:
#         Area Unit                                    ANZSOC Division  \
# 0    Aniseed Hill                         Theft and Related Offences
# 1    Aniseed Hill  Unlawful Entry With Intent/Burglary, Break and...
# 2    Aniseed Hill  Unlawful Entry With Intent/Burglary, Break and...
# 3     Brightwater                      Acts Intended to Cause Injury
# 4     Brightwater                      Acts Intended to Cause Injury
# ..            ...                                                ...
# 860     Wakefield  Unlawful Entry With Intent/Burglary, Break and...
# 861     Wakefield  Unlawful Entry With Intent/Burglary, Break and...
# 862     Wakefield  Unlawful Entry With Intent/Burglary, Break and...
# 863     Wakefield  Unlawful Entry With Intent/Burglary, Break and...
# 864     Wakefield  Unlawful Entry With Intent/Burglary, Break and...
#
#      Year Month         Region  Victimisations
# 0    2022-12-01  Tasman Region               2
# 1    2022-01-01  Tasman Region               1
# 2    2021-09-01  Tasman Region               2
# 3    2021-02-01  Tasman Region               1
# 4    2022-02-01  Tasman Region               2
# ..          ...            ...             ...
# 860  2021-03-01  Tasman Region               1
# 861  2021-06-01  Tasman Region               1
# 862  2020-10-01  Tasman Region               2
# 863  2022-10-01  Tasman Region               2
# 864  2021-11-01  Tasman Region               1
#
# [865 rows x 5 columns]

# %%
df_all['Year'] = df_all['Year Month'].str[:4]
df_all['Month'] = df_all['Year Month'].str[5:7]
df_all = df_all[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df_all
# Out:
#         Area Unit                                    ANZSOC Division  Year  \
# 0    Aniseed Hill                         Theft and Related Offences  2022
# 1    Aniseed Hill  Unlawful Entry With Intent/Burglary, Break and...  2022
# 2    Aniseed Hill  Unlawful Entry With Intent/Burglary, Break and...  2021
# 3     Brightwater                      Acts Intended to Cause Injury  2021
# 4     Brightwater                      Acts Intended to Cause Injury  2022
# ..            ...                                                ...   ...
# 860     Wakefield  Unlawful Entry With Intent/Burglary, Break and...  2021
# 861     Wakefield  Unlawful Entry With Intent/Burglary, Break and...  2021
# 862     Wakefield  Unlawful Entry With Intent/Burglary, Break and...  2020
# 863     Wakefield  Unlawful Entry With Intent/Burglary, Break and...  2022
# 864     Wakefield  Unlawful Entry With Intent/Burglary, Break and...  2021
#
#             Region  Victimisations
# 0    Tasman Region               2
# 1    Tasman Region               1
# 2    Tasman Region               2
# 3    Tasman Region               1
# 4    Tasman Region               2
# ..             ...             ...
# 860  Tasman Region               1
# 861  Tasman Region               1
# 862  Tasman Region               2
# 863  Tasman Region               2
# 864  Tasman Region               1
#
# [865 rows x 5 columns]

# %%
df = pd.read_csv("/Users/momoko/Desktop/NZ_Crime/Data/2023_data/Tasman.csv", sep="\t", encoding="utf-16")
df.index = range(len(df))
df['Year'] = df['Year Month'].str[5:]
df['Month'] = df['Year Month'].str[2:4]
df = df[["Area Unit", "ANZSOC Division", "Year", "Region","Victimisations"]]
df
# Out:
#            Area Unit                          ANZSOC Division  Year  \
# 0     Richmond West.               Theft and Related Offences  2023
# 1            Takaka.            Acts Intended to Cause Injury  2023
# 2      Motueka West.               Theft and Related Offences  2023
# 3              Hope.  Robbery, Extortion and Related Offences  2023
# 4     Richmond West.            Acts Intended to Cause Injury  2023
# ...              ...                                      ...   ...
# 1533  Richmond East.               Theft and Related Offences  2023
# 1534   Motueka West.            Acts Intended to Cause Injury  2023
# 1535    Kaiteriteri.               Theft and Related Offences  2023
# 1536    Kaiteriteri.               Theft and Related Offences  2023
# 1537        Wai-Iti.               Theft and Related Offences  2023
#
#              Region  Victimisations
# 0     Tasman Region               1
# 1     Tasman Region               1
# 2     Tasman Region               1
# 3     Tasman Region               1
# 4     Tasman Region               1
# ...             ...             ...
# 1533  Tasman Region               1
# 1534  Tasman Region               1
# 1535  Tasman Region               1
# 1536  Tasman Region               1
# 1537  Tasman Region               1
#
# [1538 rows x 5 columns]
